# %%
import numpy as np
import pandas as pd

# %%
uv_sed = np.loadtxt('uv_sed.txt')
uv_sed = pd.DataFrame({'band': ['UV'] * len(uv_sed), 'flux': })
vis_sed = np.loadtxt('vis_sed.txt')

# %%
pd.read_csv('alf Dra.phot',delimiter='|')
# Out:
#     Unnamed: 0          band                  meas                    emeas   \
# 0          NaN       GAIA2.G                 3.5478                  0.0026
# 1          NaN      GAIA2.BP                 3.6942                   0.014
# 2          NaN      GAIA2.RP                 3.6567                  0.0036
# 3          NaN   STROMGREN.Y                 3.6600                     nan
# 4          NaN       2MASS.J                 3.4340      0.3059999942779541
# 5          NaN       2MASS.H                 3.6330      0.2240000069141388
# 6          NaN      2MASS.KS                 3.6390      0.2720000147819519
# 7          NaN        SDSS.U                 9.4940    0.006000000052154064
# 8          NaN        SDSS.G                 7.6100    0.004000000189989805
# 9          NaN        SDSS.R                 7.6560   0.0010000000474974513
# 10         NaN        SDSS.I                 6.8520    0.004999999888241291
# ...

# %%
vis_sed
# Out:
# array([[3.2250e+03, 1.3930e-10],
#        [3.2750e+03, 1.3520e-10],
#        [3.3250e+03, 1.3130e-10],
#        [3.3750e+03, 1.2700e-10],
#        [3.4250e+03, 1.2590e-10],
#        [3.4750e+03, 1.2180e-10],
#        [3.5250e+03, 1.2070e-10],
#        [3.5750e+03, 1.1880e-10],
#        [3.6250e+03, 1.1690e-10],
#        [3.6750e+03, 1.1640e-10],
#        [3.7250e+03, 1.2160e-10],
#        [3.7750e+03, 1.7560e-10],
#        [3.8250e+03, 2.2860e-10],
#        [3.8750e+03, 2.7810e-10],
#        [3.9250e+03, 2.9080e-10],
#        [3.9750e+03, 2.0760e-10],
#        [4.0250e+03, 3.0730e-10],
#        [4.0750e+03, 2.6670e-10],
#        [4.1250e+03, 2.4740e-10],
#        [4.1750e+03, 2.7180e-10],
#        [4.2250e+03, 2.6900e-10],
#        [4.2750e+03, 2.5710e-10],
#        [4.3250e+03, 2.0430e-10],
#        [4.3750e+03, 2.2240e-10],
#        [4.4250e+03, 2.2900e-10],
#        [4.4750e+03, 2.2320e-10],
#        [4.5250e+03, 2.1700e-10],
#        [4.5750e+03, 2.1000e-10],
# ...
